# %%
import numpy as np
import pandas as pd
    
df1 = pd.read_csv('/Users/Maxim/Desktop/Data_Mining/Project/Data/historical_data1_Q12016.txt', low_memory=False, sep="|", header=None, \
                  names=['1. creditScore', '2. FirstPayment', '3. FirstTimeHomebuyer', '4. Maturity', '5. MetropolitanArea', '6. MorgageInsurancePercentage', '7. HouseUnits', '8. OccupancyStatus', '9. CombinedLoanToValue','10. DebtToIncome', '11. UPB', '12. OriginalLoanToValue', '13. OrigninalInterestRate', '14. Channel', '15. PrepaymentPenaltyMorgageFlag', '16. ProductType', '17. PropertyState', '18. PropertyType', '19. ZipCode', '20. LoanSequenceNo', '21. LoanPurpose', '22. OriginalLoanTerm', '23. NumberOfBorrowers', '24. SellerName', '25. ServiceName', '26. SuperConformFlag', '27. preHARPP'])
                  # dtypes={'1. creditScore': np.int})
df1.replace('',np.NaN)
df1.replace('NaN',np.NaN)
display(df.dtypes)
with pd.option_context('display.max_rows', 10, 'display.max_columns', None):
    display(df1)
# Out:
# 1. creditScore                       object
# 2. FirstPayment                       int64
# 3. FirstTimeHomebuyer                object
# 4. Maturity                           int64
# 5. MetropolitanArea                 float64
# 6. MorgageInsurancePercentage        object
# 7. HouseUnits                         int64
# 8. OccupancyStatus                   object
# 9. CombinedLoanToValue              float64
# 10. DebtToIncome                     object
# 11. UPB                               int64
# 12. OriginalLoanToValue             float64
# 13. OrigninalInterestRate           float64
# 14. Channel                          object
# 15. PrepaymentPenaltyMorgageFlag     object
# 16. ProductType                      object
# 17. PropertyState                    object
# 18. PropertyType                     object
# 19. ZipCode                           int64
# 20. LoanSequenceNo                   object
# 21. LoanPurpose                      object
# 22. OriginalLoanTerm                  int64
# 23. NumberOfBorrowers                 int64
# 24. SellerName                       object
# 25. ServiceName                      object
# 26. SuperConformFlag                 object
# 27. preHARPP                        float64
# dtype: object
#        1. creditScore  2. FirstPayment 3. FirstTimeHomebuyer  4. Maturity  \
# 0                 818           201605                   NaN       204604
# 1                 773           201605                   NaN       203104
# 2                 772           201603                   NaN       204602
# 3                 756           201604                   NaN       204603
# 4                 686           201604                   NaN       203603
# ...               ...              ...                   ...          ...
# 277593            744           201603                     N       204602
# 277594            760           201603                   NaN       204602
# 277595            739           201603                   NaN       204602
# 277596            791           201603                   NaN       204602
# 277597            732           201603                     N       204602
#
#         5. MetropolitanArea 6. MorgageInsurancePercentage  7. HouseUnits  \
# 0                   33340.0                           000              1
# 1                   33340.0                           000              1
# 2                   36540.0                            25              1
# 3                   33340.0                           000              1
# 4                   39820.0                           000              1
# ...                     ...                           ...            ...
# 277593              37964.0                            18              1
# 277594              36140.0                           000              1
# 277595              37964.0                           000              1
# 277596              33874.0                           000              1
# 277597              37964.0                           000              1
#
#        8. OccupancyStatus  9. CombinedLoanToValue 10. DebtToIncome  11. UPB  \
# 0                       O                    80.0                8    80000
# 1                       O                    75.0               33   118000
# 2                       O                    87.0               22   157000
# 3                       O                    59.0               32   325000
# 4                       O                    65.0               41   125000
# ...                   ...                     ...              ...      ...
# 277593                  O                    97.0               43   106000
# 277594                  S                    79.0               48   417000
# 277595                  O                    68.0               30   256000
# 277596                  O                    77.0               24   356000
# 277597                  O                    90.0               36   288000
#
#         12. OriginalLoanToValue  13. OrigninalInterestRate 14. Channel  \
# 0                          80.0                      3.750           R
# 1                          75.0                      3.000           R
# 2                          87.0                      3.950           C
# 3                          59.0                      3.625           R
# 4                          65.0                      3.750           R
# ...                         ...                        ...         ...
# 277593                     97.0                      4.125           R
# 277594                     79.0                      4.000           R
# 277595                     68.0                      4.125           R
# 277596                     70.0                      4.125           R
# 277597                     80.0                      4.250           R
#
#        15. PrepaymentPenaltyMorgageFlag 16. ProductType 17. PropertyState  \
# 0                                     N             FRM                WI
# 1                                     N             FRM                WI
# 2                                     N             FRM                IA
# 3                                     N             FRM                WI
# 4                                     N             FRM                CA
# ...                                 ...             ...               ...
# 277593                              NaN             FRM                PA
# 277594                              NaN             FRM                NJ
# 277595                              NaN             FRM                PA
# 277596                              NaN             FRM                PA
# 277597                              NaN             FRM                PA
#
#        18. PropertyType  19. ZipCode 20. LoanSequenceNo 21. LoanPurpose  \
# 0                    SF        53200       F116Q1000001               N
# 1                    SF        53100       F116Q1000002               N
# 2                    SF        51500       F116Q1000003               N
# 3                    SF        53100       F116Q1000004               N
# 4                    MH        96000       F116Q1000005               C
# ...                 ...          ...                ...             ...
# 277593               SF        19000       F116Q1282321               P
# 277594               SF         8200       F116Q1282322               P
# 277595               SF        19000       F116Q1282323               C
# 277596               SF        19400       F116Q1282324               N
# 277597               SF        19000       F116Q1282325               P
#
#         22. OriginalLoanTerm  23. NumberOfBorrowers 24. SellerName  \
# 0                        360                      1  Other sellers
# 1                        180                      1  Other sellers
# 2                        360                      2       USBANKNA
# 3                        360                      2  Other sellers
# 4                        240                      2  Other sellers
# ...                      ...                    ...            ...
# 277593                   360                      1  Other sellers
# 277594                   360                      2  Other sellers
# 277595                   360                      2  Other sellers
# 277596                   360                      2  Other sellers
# 277597                   360                      2  Other sellers
#
#         25. ServiceName 26. SuperConformFlag  27. preHARPP
# 0       Other servicers                  NaN           NaN
# 1       Other servicers                  NaN           NaN
# 2              USBANKNA                  NaN           NaN
# 3       Other servicers                  NaN           NaN
# 4       Other servicers                  NaN           NaN
# ...                 ...                  ...           ...
# 277593  Other servicers                  NaN           NaN
# 277594  Other servicers                  NaN           NaN
# 277595  Other servicers                  NaN           NaN
# 277596  Other servicers                  NaN           NaN
# 277597  Other servicers                  NaN           NaN
#
# [277598 rows x 27 columns]

# %%
df2 = pd.read_csv('/Users/Maxim/Desktop/Data_Mining/Project/Data/historical_data1_time_Q12016.txt', low_memory=False, sep="|", header=None, names=['1. LoanSequenceNumber', '2. MonthlyReportingPeriod', '3. CurrentActualUPB', '4. CurrentLoanDeliquencyStatus', '5. LoanAge', '6. MonthsToLegalMaturity', '7. RepurchaseFlag', '8. ModificationFlag', '9. ZeroBalanceCode', '10. ZeroBalanceEffectiveDate', '11. CurrentInterestRate', '12. CurrentDefferedUPB', '13. DueDateLastOfPaidInstallment', '14. MorgageInsuranceRecoveries', '15. NetSalesProceeds', '16. NonMorgageInsuranceRecoveries', '17. Expenses', '18. LegalCosts', '19. MaintenanceAndPreservationCosts','20. TaxesAndInsurance', '21. MiscellaneousExpenses', '22. ActualLoss', '23. ModificationCosts'])
df2.replace('',np.NaN)
df2.replace('NaN',np.NaN)
display(df.dtypes)
with pd.option_context('display.max_rows', 10, 'display.max_columns', None):
    display(df2)
# Out:
# 1. creditScore                       object
# 2. FirstPayment                       int64
# 3. FirstTimeHomebuyer                object
# 4. Maturity                           int64
# 5. MetropolitanArea                 float64
# 6. MorgageInsurancePercentage        object
# 7. HouseUnits                         int64
# 8. OccupancyStatus                   object
# 9. CombinedLoanToValue              float64
# 10. DebtToIncome                     object
# 11. UPB                               int64
# 12. OriginalLoanToValue             float64
# 13. OrigninalInterestRate           float64
# 14. Channel                          object
# 15. PrepaymentPenaltyMorgageFlag     object
# 16. ProductType                      object
# 17. PropertyState                    object
# 18. PropertyType                     object
# 19. ZipCode                           int64
# 20. LoanSequenceNo                   object
# 21. LoanPurpose                      object
# 22. OriginalLoanTerm                  int64
# 23. NumberOfBorrowers                 int64
# 24. SellerName                       object
# 25. ServiceName                      object
# 26. SuperConformFlag                 object
# 27. preHARPP                        float64
# dtype: object
#         1. LoanSequenceNumber  2. MonthlyReportingPeriod  3. CurrentActualUPB  \
# 0                F116Q1000001                     201604             80000.00
# 1                F116Q1000001                     201605             80000.00
# 2                F116Q1000001                     201606             80000.00
# 3                F116Q1000001                     201607             80000.00
# 4                F116Q1000001                     201608             80000.00
# ...                       ...                        ...                  ...
# 4188202          F116Q1282242                     201706            258219.33
# 4188203          F116Q1282243                     201706            254000.00
# 4188204          F116Q1282244                     201706            254331.04
# 4188205          F116Q1282245                     201706            305250.00
# 4188206          F116Q1282246                     201706            259608.23
#
#         4. CurrentLoanDeliquencyStatus  5. LoanAge  6. MonthsToLegalMaturity  \
# 0                                    0           0                       360
# 1                                    0           1                       359
# 2                                    0           2                       358
# 3                                    0           3                       357
# 4                                    0           4                       356
# ...                                ...         ...                       ...
# 4188202                              0          14                       356
# 4188203                              0          14                       360
# 4188204                              0          16                       354
# 4188205                              0          14                       361
# 4188206                              0          16                       343
#
#         7. RepurchaseFlag 8. ModificationFlag  9. ZeroBalanceCode  \
# 0                     NaN                 NaN                 NaN
# 1                     NaN                 NaN                 NaN
# 2                     NaN                 NaN                 NaN
# 3                     NaN                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
#